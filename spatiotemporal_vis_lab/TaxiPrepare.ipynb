# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(filepath_or_buffer="green2016.csv",sep=',',
                         header=0, index_col=None, lineterminator='\n')

# %%
data.columns
# Out:
# Index(['VendorID', 'lpep_pickup_datetime', 'Lpep_dropoff_datetime',
#        'Store_and_fwd_flag', 'RateCodeID', 'Pickup_longitude',
#        'Pickup_latitude', 'Dropoff_longitude', 'Dropoff_latitude',
#        'Passenger_count', 'Trip_distance', 'Fare_amount', 'Extra', 'MTA_tax',
#        'Tip_amount', 'Tolls_amount', 'Ehail_fee', 'improvement_surcharge',
#        'Total_amount', 'Payment_type', 'Trip_type ', 'PULocationID',
#        'DOLocationID'],
#       dtype='object')

# %%
data.head()
# Out:
#    VendorID    lpep_pickup_datetime   Lpep_dropoff_datetime  \
# 0         2  06/15/2016 12:00:00 AM  06/15/2016 12:00:00 AM
# 1         2  06/15/2016 12:00:00 AM  06/15/2016 12:00:00 AM
# 2         2  06/15/2016 12:00:01 AM  06/15/2016 12:15:26 AM
# 3         1  06/15/2016 12:00:01 AM  06/15/2016 12:02:41 AM
# 4         1  06/15/2016 12:00:02 AM  06/15/2016 12:09:46 AM
#
#   Store_and_fwd_flag  RateCodeID  Pickup_longitude  Pickup_latitude  \
# 0                  N           1        -73.950417        40.785801
# 1                  N           1        -73.947021        40.792580
# 2                  N           1        -73.887550        40.745037
# 3                  N           1        -73.903473        40.745316
# 4                  N           1        -73.990120        40.687275
#
#    Dropoff_longitude  Dropoff_latitude  Passenger_count      ...       \
# 0         -73.961029         40.810272                2      ...
# ...

# %%
data.shape
# Out:
# (292126, 23)

# %% [markdown]
# ### Sample the data

# %%
df = data

# %%
df.shape
# Out:
# (292126, 23)

# %%
df.head()
# Out:
#    VendorID    lpep_pickup_datetime   Lpep_dropoff_datetime  \
# 0         2  06/15/2016 12:00:00 AM  06/15/2016 12:00:00 AM
# 1         2  06/15/2016 12:00:00 AM  06/15/2016 12:00:00 AM
# 2         2  06/15/2016 12:00:01 AM  06/15/2016 12:15:26 AM
# 3         1  06/15/2016 12:00:01 AM  06/15/2016 12:02:41 AM
# 4         1  06/15/2016 12:00:02 AM  06/15/2016 12:09:46 AM
#
#   Store_and_fwd_flag  RateCodeID  Pickup_longitude  Pickup_latitude  \
# 0                  N           1        -73.950417        40.785801
# 1                  N           1        -73.947021        40.792580
# 2                  N           1        -73.887550        40.745037
# 3                  N           1        -73.903473        40.745316
# 4                  N           1        -73.990120        40.687275
#
#    Dropoff_longitude  Dropoff_latitude  Passenger_count      ...       \
# 0         -73.961029         40.810272                2      ...
# ...

# %%
# to_drop = ['Store_and_fwd_flag', 'RateCodeID','Ehail_fee','PULocationID','DOLocationID']
# df = df.drop(to_drop, axis=1)
samples = df.sample(n=100000, random_state=1)

# %%
samples = samples.rename(index=str, columns={
    "lpep_pickup_datetime": "pickup_datetime",
    "Lpep_dropoff_datetime": "dropoff_datetime"
})

# %%
samples.head()
# Out:
#         VendorID         pickup_datetime        dropoff_datetime  \
# 55274          2  06/16/2016 10:18:09 AM  06/16/2016 10:32:32 AM
# 233334         2  06/19/2016 04:09:59 PM  06/19/2016 04:24:11 PM
# 13312          1  06/15/2016 11:22:07 AM  06/15/2016 11:34:03 AM
# 154110         2  06/18/2016 06:30:07 AM  06/18/2016 06:37:29 AM
# 129955         2  06/17/2016 08:53:31 PM  06/17/2016 09:05:34 PM
#
#         Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 55274         -73.978424        40.666683         -73.950439
# 233334        -73.991203        40.685532         -73.985603
# 13312         -73.954796        40.789211         -73.941444
# 154110        -73.951561        40.811962         -73.967468
# 129955        -73.986336        40.703938         -73.997955
#
#         Dropoff_latitude  Passenger_count  Trip_distance  Fare_amount  Extra  \
# 55274          40.681030                1           2.58         11.5    0.0
# ...

# %%
samples.shape
# Out:
# (100000, 18)

# %%
samples.to_csv('sampled_taxi.csv', sep=',', header=samples.columns, index=False)
